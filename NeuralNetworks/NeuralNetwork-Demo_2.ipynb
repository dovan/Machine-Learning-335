# %%
#Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Load MNIST Data
#
# The MNIST dataset consists of 70,000 28x28 images of handwritten digits

# %%
#load dataset

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data() #train-test 0.75-0.25 split

# %%
# summarize loaded dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
#normalize data by scaling
#data range from 0-255 scaled to 0-1 , dividing by 255

x_train = x_train / 255
x_test = x_test / 255

# %%
#flatten x grids into longitutdal input

print("before flattening, shape of each x_train data is ", x_train[0].shape)

image_vector_size = 28*28

x_train = x_train.reshape(len(x_train), image_vector_size)
x_test = x_test.reshape(len(x_test), image_vector_size)

print("after flattening, shape of each x_train data is ", x_train[0].shape)
# Out:
# before flattening, shape of each x_train data is  (28, 28)
# after flattening, shape of each x_train data is  (784,)

# %% [markdown]
# # Neural Network Architecture

# %% [markdown]
# ## Neural Network model with one hidden layer with 32 neurons

# %%
# Define Neural Network model architecture with one hidden layer with 32 neurons

image_size = 784 # 28*28
num_classes = 10 # ten unique digits

model = Sequential()
model.add(Dense(units=32, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                25120
#
#  dense_1 (Dense)             (None, 10)                330
#
# ...
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile and train the neural network model

model.compile(optimizer="sgd", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history= model.fit(x_train, y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=0)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy- one hidden layer with 32 neurons')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# ## Neural Network model with two hidden layers with 32 neurons in each

# %%
# Define Neural Network model architecture with two hidden layers with 32 neurons in each

image_size = 784 # 28*28
num_classes = 10 # ten unique digits

model = Sequential()
model.add(Dense(32, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

#compile and train the neural network model

model.compile(optimizer="sgd", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history= model.fit(x_train, y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=0)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy- two hidden layers with 32 neurons in each')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 32)                25120
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dense_4 (Dense)             (None, 10)                330
#
# ...
# Total params: 26,506
# Trainable params: 26,506
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Neural Network model with three hidden layers with 32 neurons in each

# %%
# Define Neural Network model architecture with three hidden layers with 32 neurons in each

image_size = 784 # 28*28
num_classes = 10 # ten unique digits

model = Sequential()
model.add(Dense(32, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

#compile and train the neural network model

model.compile(optimizer="sgd", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history= model.fit(x_train, y_train, batch_size=10, epochs=50, validation_split=0.2, verbose=0)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy- three hidden layers with 32 neurons in each')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 32)                25120
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  dense_7 (Dense)             (None, 32)                1056
#
#  dense_8 (Dense)             (None, 10)                330
#
# ...
# Total params: 27,562
# Trainable params: 27,562
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Neural Network model with one hidden layers with 96 neurons

# %%
# Define Neural Network model architecture with one hidden layers with 96 neurons

image_size = 784 # 28*28
num_classes = 10 # ten unique digits

model = Sequential()
model.add(Dense(96, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()

#compile and train the neural network model

model.compile(optimizer="sgd", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history= model.fit(x_train, y_train, batch_size=10, epochs=50, validation_split=0.2, verbose=0)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy-one hidden layer with 96 neurons')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 96)                75360
#
#  dense_10 (Dense)            (None, 10)                970
#
# ...
# Total params: 76,330
# Trainable params: 76,330
# Non-trainable params: 0
# _________________________________________________________________
