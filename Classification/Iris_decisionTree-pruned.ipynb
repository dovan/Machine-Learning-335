# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.inspection import DecisionBoundaryDisplay

# %%
# Load data
iris = load_iris()

# Extracting Attributes / Features
X = iris.data

# Extracting Target / Class Labels
y = iris.target

# Extracting Feature Names
features=iris.feature_names

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth=3) #clf to denote classifier
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
tree.plot_tree(clf, feature_names=features)
# Out:
# [Text(0.375, 0.875, 'petal length (cm) <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5, 0.625, 'petal width (cm) <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.25, 0.375, 'petal length (cm) <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.125, 0.125, 'entropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.375, 0.125, 'entropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.75, 0.375, 'petal length (cm) <= 4.85\nentropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.625, 0.125, 'entropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
#install 'graphviz' package using "conda install python-graphviz" from Anaconda Promt

import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=iris.feature_names,  
                     class_names=iris.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
#evaluation

y_pred = clf.predict(X)

print(confusion_matrix(y, y_pred))
print(classification_report(y, y_pred))
# Out:
# [[50  0  0]
#  [ 0 47  3]
#  [ 0  1 49]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       0.98      0.94      0.96        50
#            2       0.94      0.98      0.96        50
#
#     accuracy                           0.97       150
#    macro avg       0.97      0.97      0.97       150
# weighted avg       0.97      0.97      0.97       150
